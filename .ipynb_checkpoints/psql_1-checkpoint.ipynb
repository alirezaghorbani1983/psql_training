# %%
import sqlite3

# %%
# !pip install ipython-sql
# Out:
# ...
#
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ------------------------------ --------- 3/4 [ipython-sql]
#    ---------------------------------------- 4/4 [ipython-sql]
#
# ...

# %%
# %load_ext sql

# %% [markdown]
# ## connect to sqlite  database

# %%
# %sql sqlite:///mydb.sqlite
